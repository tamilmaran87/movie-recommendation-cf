# %% [markdown]
# Importing the library

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection And Analysis

# %%
#load the diabets dataset into the pandas dataframe
diabetes_dataset = pd.read_csv('/content/diabetes.csv')

# %%
diabetes_dataset.head()

# %%
diabetes_dataset.shape

# %%
diabetes_dataset.isnull().sum()

# %%
diabetes_dataset.describe()

# %%
diabetes_dataset['Outcome'].value_counts()

# %% [markdown]
# 0--->Non-Diabets
#
# 1--->Diabets

# %%
diabetes_dataset.groupby('Outcome').mean()

# %%
#separting data & label
x=diabetes_dataset.drop(columns='Outcome',axis=1)
y=diabetes_dataset['Outcome']
print(x)
print(y)

# %% [markdown]
# Data Standaraization

# %%
scaler=StandardScaler()
scaler.fit(x)
standard_data=scaler.transform(x)
x=standard_data

# %%
print(x)

# %% [markdown]
# Spliting Training and Testing Data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)

# %% [markdown]
# Training The Model

# %%
classifier=svm.SVC(kernel='linear')

# %%
#training the support vector machine classifier
classifier.fit(x_train,y_train)

# %% [markdown]
# Model Evalution

# %%
#Accuracy score on the training data
x_train_predication=classifier.predict(x_train)
training_data_accuracy=accuracy_score(x_train_predication,y_train)
print("Accurary score of the training data:",training_data_accuracy)

# %%
#Accuracy score on the testing data
x_test_predication=classifier.predict(x_test)
testing_data_accuracy=accuracy_score(x_test_predication,y_test)
print("Accurary score of the testing data:",testing_data_accuracy)

# %% [markdown]
# Making a Predicative system

# %%
input_data=(1,85,66,29,0,26.6,0.351,31)

# %%
#changing the input data to numpy array
input_data_numpy=np.asarray(input_data)

# %%
input_data_reshaped = input_data_numpy.reshape(1, -1)
std_data = scaler.transform(input_data_reshaped)
print(std_data)

# %%
#separting data & label
x=diabetes_dataset.drop(columns='Outcome',axis=1)
y=diabetes_dataset['Outcome']

# Re-execute the cell to define the scaler object
scaler=StandardScaler()
scaler.fit(x)
standard_data=scaler.transform(x)
x=standard_data

# Re-execute the cell to define the classifier object
classifier=svm.SVC(kernel='linear')
classifier.fit(x_train,y_train)

# %%
predication=classifier.predict(std_data)
print(predication)
if(predication[0]==0):
  print("The person is not diabets")
else:
  print("The person is diabets")
